# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 48) # view num of columns
pd.set_option('display.max_rows', 48)

# %%
df
df.head() #gets the first 5 rows, fill in parameter for num of rows
# df.tail() #gets the last 5 rows, fill in paramater for num of rows
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df.shape
# shape is an attribute, not a method. shows rows and cols
# Out:
# (83439, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com"]
}

# %%
df_people = pd.DataFrame(people)
df_people #dataframe is a container for multiple series
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_people['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df_people['email']) #series is a list of data, rows of a single column, 1D array
# Out:
# pandas.core.series.Series

# %%
df_people[['last', 'email']] #passed a list inside inner brackets
#no longer a series, it is now a filtered out dataframe
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df_people.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# iloc access location using intger location
df_people.iloc[0] #access the first row, index of 0
#sets index to column name

df_people.iloc[[0,1]]

df_people.iloc[[0,1], 2] #gets email address of the first 2 rows
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
#loc search by index (label)
df_people.loc[0]
df_people.loc[[0,1], ['email', 'last']] #selects index 0 and 1's email and last name
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['Country']
# Out:
# ResponseId
# 1                                                 Slovakia
# 2                                              Netherlands
# 3                                       Russian Federation
# 4                                                  Austria
# 5        United Kingdom of Great Britain and Northern I...
#                                ...
# 83435                             United States of America
# 83436                                                Benin
# 83437                             United States of America
# 83438                                               Canada
# 83439                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
df['Country'].value_counts()
#counts num of responses for each answer
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
#grab specific row and col
# df.loc[0, 'Country']

# %%
# df.loc[[0,1,2], 'Country']

# %%
#slicing to grab multiple rows and cols
#slice is a single range, so no need for list
df.loc[0:2, 'Country']
# Out:
# ResponseId
# 1       Slovakia
# 2    Netherlands
# Name: Country, dtype: object

# %%
df.loc[0:2, 'Country':'CompFreq']
#choose splicing rows and slice from what to what cols
# Out:
#                 Country US_State UK_Country  \
# ResponseId
# 1              Slovakia      NaN        NaN
# 2           Netherlands      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# 2           Other online resources (ex: videos, blogs, etc...         7
#
#            YearsCodePro            DevType             OrgSize  \
# ResponseId
# 1                   NaN  Developer, mobile  20 to 99 employees
# 2                   NaN                NaN                 NaN
#
#                      Currency  CompTotal CompFreq
# ResponseId
# 1           EUR European Euro     4800.0  Monthly
# ...

# %%
# df_people.set_index('email', inplace=True)

#sets index, gives a unique identifier for the row

# %%
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_people.index
#lists all indexes
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# df_people.loc['CoreyMSchafer@gmail.com', 'last']

# %%
df_people.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
# df_people.reset_index(inplace=True)
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
schema_df.loc['Country', 'question']

#how to see the full question
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
schema_df.sort_index()
#sorting indexes in ascending order, inplace=True if you want to perma change
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
#filter rows
filt = df_people['last'] == 'Doe'

# %%
df_people[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df_people.loc[filt, 'email']
#[rows, cols we want]
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
# &
filt = (df_people['last'] == 'Doe') & (df_people['first'] == 'John')
df_people.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
# |
filt = (df_people['last'] == 'Doe') | (df_people['first'] == 'John')
df_people.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
# ~
df_people.loc[~filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# Name: email, dtype: object

# %%
high_salary = df['CompTotal'] > 70000
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']

# %%
df.loc[high_salary, ['Country', 'LanguageHaveWorkedWith', 'CompTotal']]
# Out:
#                              Country  \
# ResponseId
# 13                           Germany
# 25                           Germany
# 27                       Switzerland
# 30                Russian Federation
# 37          United States of America
# ...                              ...
# 83433                         Canada
# 83434                         Brazil
# 83435       United States of America
# 83436                          Benin
# 83438                         Canada
#
#                                        LanguageHaveWorkedWith  CompTotal
# ResponseId
# 13                                       C;C++;Java;Perl;Ruby    71500.0
# 25          C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...    72000.0
# 27                                                 C++;Python    80000.0
# 30                                            Delphi;Java;SQL   200000.0
# 37                                Assembly;C;Java;Kotlin;Rust   103000.0
# ...

# %%
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# ResponseId
# 9          India
# 13       Germany
# 18        Canada
# 21       Germany
# 23         India
#           ...
# 83416    Germany
# 83418      India
# 83425    Germany
# 83433     Canada
# 83438     Canada
# Name: Country, Length: 19148, dtype: object

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
#setting string in that col if it contains python
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
#change col name
# df_people.columns = ['first_name', 'last_name', 'email']
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
#use list comprehensions to change uppercase to lowercase
df_people.columns = [x.lower() for x in df_people.columns]
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# replace
df_people.columns = df_people.columns.str.replace(' ', '_')
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
#rename/update cols
df_people.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
#update values
df_people.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
#change data back
df_people.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_people.loc[2, 'last']  = 'Smith'
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df_people.at[2, 'last']  = 'Doe'
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = df_people['email'] == 'JohnDoe@email.com'
df_people[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object
